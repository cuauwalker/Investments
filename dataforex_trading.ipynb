# %% [markdown]
# # Trading Session
#
# Basic statistics are obtained before performing a trading session in the FOREX market among most important developed and emergency currencies. The scope is to apply Python codes and instructions to get basic statistics.
# At the end it is shown pairplots and the correlation matrix to help build a portfolio.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataforex=pd.read_csv('C:Desktop/Python_projects/forexrets.csv')

# %%
dataforex.head()
# Out:
#            Date     EUR     CHF     GBP     CAD     MXN     TRY     ZAR
# 0  Jan 02, 2019  0.0107  0.0088 -0.0111 -0.0045 -0.0041  0.0202  0.0054
# 1  Jan 03, 2019 -0.0043 -0.0035  0.0018 -0.0066  0.0030  0.0122 -0.0112
# 2  Jan 04, 2019 -0.0001 -0.0002  0.0075 -0.0085 -0.0106 -0.0248 -0.0238
# 3  Jan 06, 2019 -0.0015 -0.0006  0.0003 -0.0004 -0.0012 -0.0005  0.0030
# 4  Jan 07, 2019 -0.0056 -0.0063  0.0038 -0.0053 -0.0018  0.0105 -0.0093

# %%
dataforex.describe()
# Out:
#               EUR         CHF         GBP         CAD         MXN         TRY  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     0.000251    0.000343    0.000322   -0.000114   -0.000281    0.001262
# std      0.003237    0.002749    0.005190    0.003541    0.004928    0.011115
# min     -0.008800   -0.006900   -0.011200   -0.009700   -0.010600   -0.040100
# 25%     -0.001500   -0.000775   -0.002675   -0.001875   -0.003475   -0.001900
# 50%      0.000100    0.000000   -0.000150    0.000100   -0.000100    0.000800
# 75%      0.001800    0.001600    0.002250    0.001800    0.002275    0.004975
# max      0.010700    0.010200    0.020200    0.010600    0.013400    0.054400
#
#               ZAR
# count  102.000000
# mean     0.000083
# std      0.007978
# min     -0.023800
# 25%     -0.003575
# 50%     -0.000150
# 75%      0.005250
# max      0.021300

# %%
sns.pairplot(dataforex)

# %%
# Based on the correlation matrix and the pairplots, how would you build your portfolio in such a way to diversify risk?
dataforex.corr()
# Out:
#           EUR       CHF       GBP       CAD       MXN       TRY       ZAR
# EUR  1.000000  0.718623 -0.428120  0.433272  0.416071  0.180360  0.514480
# CHF  0.718623  1.000000 -0.297887  0.227978  0.271934  0.050723  0.296116
# GBP -0.428120 -0.297887  1.000000 -0.350301 -0.208515 -0.160842 -0.312578
# CAD  0.433272  0.227978 -0.350301  1.000000  0.396935  0.300233  0.581382
# MXN  0.416071  0.271934 -0.208515  0.396935  1.000000  0.326847  0.642317
# TRY  0.180360  0.050723 -0.160842  0.300233  0.326847  1.000000  0.441582
# ZAR  0.514480  0.296116 -0.312578  0.581382  0.642317  0.441582  1.000000
